# %% [markdown]
# Merging the 2 files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.patches as patches

# %%
df1 = pd.read_csv("file1.csv")
df2 = pd.read_csv("file2.csv")

# %%
k1 = list(df1)
k2 = list(df2)
k = [x for x in k1 if x in k2]
k
# Out:
# ['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name']

# %% [markdown]
# Analysing the difference between the columns Group_Name and Sub_Group_Name

# %%
print(df1["Group_Name"].unique())
print(df1["Sub_Group_Name"].unique())
# Out:
# ['Rape' 'Kidnapping & Abduction - Women & Girls' 'Dowry Deaths'
#  'Molestation' 'Sexual harassment' 'Cruelty by Husband and Relatives'
#  'Importation of Girls' 'Immoral Traffic (Prevention) Act'
#  'Indecent Representation of Women (Prohibition) Act'
#  'Sati Prevention Act' 'Total Crime Against Women']
# ['01. Rape' '02. Kidnapping & Abduction of Women & Girls'
#  '03. Dowry Deaths' '04. Molestation' '05. Sexual Harassment'
#  '06. Cruelty by Husband and Relatives' '07. Importation of Girls'
#  '08. Immoral Traffic Prevention Act' '09. Dowry Prohibition Act'
#  '10. Indecent Representation of Women(Prohibition) Act'
#  '11. Sati Prevention Act' '12. Total Crimes Against Women']

# %% [markdown]
# On Analysing dataset1 we observed that Group_Name gives 11 values where as Sub_Group_Name gives 12. This was due to an error in the dataset where Importation of Girls was added as the Group_Name for the Sub_Group_Name Dowry Prohibition Act
# On Analysing dataset2 there was no such error found.
# To prevent any discrepency in the merged data it was decideded to drop the Group_Name column in both datasets.

# %%
df1 = df1.drop(["Group_Name"], axis=1)
df2 = df2.drop(["Group_Name"], axis=1)

# %% [markdown]
# However it was observed that,
# Dataset 1 - Sub_Group_Name = 09. Dowry Prohibition Act
# Dataset 2 - Sub_Group_Name = 09. Dowry Prohibition
# To avoid any loss of data due to this all such values in Dataset 2 are replaced with 09. Dowry Prohibition Act

# %%
df2 = df2.replace(to_replace="09. Dowry Prohibition", value="09. Dowry Prohibition Act")

# %%
k1 = list(df1)
k2 = list(df2)
k = [x for x in k1 if x in k2]
k
# Out:
# ['Area_Name', 'Year', 'Sub_Group_Name']

# %%
df = pd.merge(df1, df2, on=k)

# %%
cond = df[(df['Sub_Group_Name'] == "08. Immoral Traffic Prevention Act") | (df['Sub_Group_Name']== "09. Dowry Prohibition Act") | (df['Sub_Group_Name'] == "10. Indecent Representation of Women(Prohibition) Act") | (df['Sub_Group_Name'] == "11. Sati Prevention Act")].index
df.drop(cond , inplace=True)
df["Sub_Group_Name"].unique()
# Out:
# array(['01. Rape', '02. Kidnapping & Abduction of Women & Girls',
#        '03. Dowry Deaths', '04. Molestation', '05. Sexual Harassment',
#        '06. Cruelty by Husband and Relatives', '07. Importation of Girls',
#        '12. Total Crimes Against Women'], dtype=object)

# %%
df.to_csv('Crime_Against_Women.csv')

# %%
df.shape
# Out:
# (2765, 33)

# %%
total_df = df[df['Sub_Group_Name']=='12. Total Crimes Against Women']
#total_df.groupby(['Area_Name','Year']).first()
total_df
# Out:
#                       Area_Name  Year                  Sub_Group_Name  \
# 3850  Andaman & Nicobar Islands  2001  12. Total Crimes Against Women
# 3851             Andhra Pradesh  2001  12. Total Crimes Against Women
# 3852          Arunachal Pradesh  2001  12. Total Crimes Against Women
# 3853                      Assam  2001  12. Total Crimes Against Women
# 3854                      Bihar  2001  12. Total Crimes Against Women
# ...                         ...   ...                             ...
# 4160                 Tamil Nadu  2010  12. Total Crimes Against Women
# 4161                    Tripura  2010  12. Total Crimes Against Women
# 4162              Uttar Pradesh  2010  12. Total Crimes Against Women
# 4163                Uttarakhand  2010  12. Total Crimes Against Women
# 4164                West Bengal  2010  12. Total Crimes Against Women
#
#       Cases_Acquitted_or_Discharged  \
# 3850                             14
# 3851                           6773
# 3852                             12
# 3853                           1289
# 3854                           1760
# ...                             ...
# 4160                           2823
# 4161                            683
# 4162                           6976
# 4163                            308
# 4164                           4084
#
#       Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 3850                                                  6
# 3851                                                236
# 3852                                                 22
# 3853                                               1031
# 3854                                                627
# ...                                                 ...
# 4160                                                565
# 4161                                                102
# 4162                                               3746
# 4163                                                185
# 4164                                               1110
#
#       Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# 3850                   40                              0                0
# 3851                13848                           1849             4765
# 3852                  138                              7               36
# 3853                 2115                            154              302
# 3854                 4307                            196              768
# ...                   ...                            ...              ...
# 4160                 4780                             13             1749
# 4161                 1360                             74               95
# 4162                14401                            366            10307
# 4163                  864                             17              499
# 4164                23528                            125              435
#
#       Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# 3850                                                  0
# 3851                                               2067
# 3852                                                  0
# 3853                                                322
# 3854                                                401
# ...                                                 ...
# 4160                                                708
# 4161                                                 15
# 4162                                               1704
# 4163                                                 47
# 4164                                                120
#
#       Cases_Investigated_Chargesheets+FR_Submitted  ...  Persons_Arrested  \
# 3850                                            46  ...                34
# 3851                                         14084  ...             22218
# 3852                                           160  ...               218
# 3853                                          3146  ...              5497
# 3854                                          4934  ...             13034
# ...                                            ...  ...               ...
# 4160                                          5345  ...              9649
# 4161                                          1462  ...              2127
# 4162                                         18147  ...             58330
# 4163                                          1049  ...              1750
# 4164                                         24638  ...             26549
#
#       Persons_Chargesheeted  Persons_Convicted  \
# 3850                     49                  0
# 3851                  19991               4142
# 3852                    169                 40
# 3853                   3120                410
# 3854                  10975               1495
# ...                     ...                ...
# 4160                   8841               2809
# 4161                   1611                144
# 4162                  41235              27706
# 4163                   1683               1075
# 4164                  28005                628
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning  \
# 3850                                                 33
# 3851                                               5485
# 3852                                                 70
# 3853                                               3930
# 3854                                               5878
# ...                                                 ...
# 4160                                               3407
# 4161                                                408
# 4162                                               6897
# 4163                                                241
# 4164                                              12367
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_end  \
# 3850                                                 18
# 3851                                               6862
# 3852                                                 70
# 3853                                               4700
# 3854                                               6319
# ...                                                 ...
# 4160                                               4038
# 4161                                                584
# 4162                                               7934
# 4163                                                231
# 4164                                               9661
#
#       Persons_in_Custody_or_on_Bail_during_Trial_at_Year_End  \
# 3850                                                204
# 3851                                              29935
# 3852                                                854
# 3853                                              10002
# 3854                                              39450
# ...                                                 ...
# 4160                                              21259
# 4161                                               2183
# 4162                                             116367
# 4163                                               5764
# 4164                                             124734
#
#       Persons_Released_or_Freed_by_Police_or_Magistrate_before_Trial_for_want_of_evidence_or_any_other_reason  \
# 3850                                                  0
# 3851                                                850
# 3852                                                 49
# 3853                                               1607
# 3854                                               1618
# ...                                                 ...
# 4160                                                177
# 4161                                                340
# 4162                                              16058
# 4163                                                 77
# 4164                                               1250
#
#       Persons_Trial_Completed  Persons_under_Trial_at_Year_beginning  \
# 3850                       16                                    171
# 3851                    15104                                  27636
# 3852                       55                                    749
# 3853                     2269                                   9385
# 3854                     6547                                  35633
# ...                       ...                                    ...
# 4160                     8392                                  20814
# 4161                     1467                                   2193
# 4162                    48532                                 125133
# 4163                     2127                                   6286
# 4164                    12000                                 109399
#
#       Total_Persons_under_Trial
# 3850                        220
# 3851                      47627
# 3852                        918
# 3853                      12505
# 3854                      46608
# ...                         ...
# 4160                      29655
# 4161                       3804
# 4162                     166368
# 4163                       7969
# 4164                     137404
#
# [315 rows x 33 columns]

# %%
df = df[df['Sub_Group_Name']!='12. Total Crimes Against Women']
df["Sub_Group_Name"].unique()
# Out:
# array(['01. Rape', '02. Kidnapping & Abduction of Women & Girls',
#        '03. Dowry Deaths', '04. Molestation', '05. Sexual Harassment',
#        '06. Cruelty by Husband and Relatives', '07. Importation of Girls'],
#       dtype=object)

# %%
zero= dict()
for column_name in df.columns:
    column = df[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    zero[column_name] = ((count/df.shape[0])*100).round(3)
zero
# Out:
# {'Area_Name': 0.0,
#  'Year': 0.0,
#  'Sub_Group_Name': 0.0,
#  'Cases_Acquitted_or_Discharged': 28.204,
#  'Cases_charge_sheets_were_not_laid_but_Final_Report_submitted': 35.469,
#  'Cases_Chargesheeted': 22.408,
#  'Cases_Compounded_or_Withdrawn': 56.367,
#  'Cases_Convicted': 33.551,
#  'Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law': 48.408,
#  'Cases_Investigated_Chargesheets+FR_Submitted': 20.898,
#  'Cases_not_Investigated_or_in_which_investigation_was_refused': 85.837,
#  'Cases_Pending_Investigation_at_Year_End': 23.102,
#  'Cases_Pending_Investigation_from_previous_year': 23.878,
#  'Cases_Pending_Trial_at_Year_End': 17.959,
#  'Cases_Pending_Trial_from_the_previous_year': 18.49,
#  'Cases_Reported': 20.408,
#  'Cases_Sent_for_Trial': 22.408,
#  'Cases_Trials_Completed': 25.184,
#  'Cases_Withdrawn_by_the_Govt': 97.551,
#  'Cases_withdrawn_by_the_Govt_during_investigation': 96.898,
#  'Total_Cases_for_Trial': 16.286,
#  'Persons_Acquitted': 27.959,
#  'Persons_against_whom_cases_Compounded_or_Withdrawn': 56.939,
#  'Persons_Arrested': 21.796,
#  'Persons_Chargesheeted': 22.653,
#  'Persons_Convicted': 34.082,
#  'Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning': 28.163,
#  'Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_end': 27.673,
#  'Persons_in_Custody_or_on_Bail_during_Trial_at_Year_End': 19.102,
#  'Persons_Released_or_Freed_by_Police_or_Magistrate_before_Trial_for_want_of_evidence_or_any_other_reason': 52.857,
#  'Persons_Trial_Completed': 25.51,
#  'Persons_under_Trial_at_Year_beginning': 19.592,
#  'Total_Persons_under_Trial': 17.469}

# %%
sorted_value_index = np.argsort(zero.values())
dictionary_keys = list(zero.keys())
zero = {dictionary_keys[i]: sorted(
    zero.values())[i] for i in range(len(dictionary_keys))}
print(zero)
# Out:
# {'Area_Name': 0.0, 'Year': 0.0, 'Sub_Group_Name': 0.0, 'Cases_Acquitted_or_Discharged': 16.286, 'Cases_charge_sheets_were_not_laid_but_Final_Report_submitted': 17.469, 'Cases_Chargesheeted': 17.959, 'Cases_Compounded_or_Withdrawn': 18.49, 'Cases_Convicted': 19.102, 'Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law': 19.592, 'Cases_Investigated_Chargesheets+FR_Submitted': 20.408, 'Cases_not_Investigated_or_in_which_investigation_was_refused': 20.898, 'Cases_Pending_Investigation_at_Year_End': 21.796, 'Cases_Pending_Investigation_from_previous_year': 22.408, 'Cases_Pending_Trial_at_Year_End': 22.408, 'Cases_Pending_Trial_from_the_previous_year': 22.653, 'Cases_Reported': 23.102, 'Cases_Sent_for_Trial': 23.878, 'Cases_Trials_Completed': 25.184, 'Cases_Withdrawn_by_the_Govt': 25.51, 'Cases_withdrawn_by_the_Govt_during_investigation': 27.673, 'Total_Cases_for_Trial': 27.959, 'Persons_Acquitted': 28.163, 'Persons_against_whom_cases_Compounded_or_Withdrawn': 28.204, 'Persons_Arrested': 33.551, 'Persons_Chargesheeted': 34.082, 'Persons_Convicted': 35.469, 'Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning': 48.408, 'Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_end': 52.857, 'Persons_in_Custody_or_on_Bail_during_Trial_at_Year_End': 56.367, 'Persons_Released_or_Freed_by_Police_or_Magistrate_before_Trial_for_want_of_evidence_or_any_other_reason': 56.939, 'Persons_Trial_Completed': 85.837, 'Persons_under_Trial_at_Year_beginning': 96.898, 'Total_Persons_under_Trial': 97.551}

# %%
for key,value in zero.items():
  if (value>=50):
    print(key,value)
    del df[key]
# Out:
# Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_end 52.857
# Persons_in_Custody_or_on_Bail_during_Trial_at_Year_End 56.367
# Persons_Released_or_Freed_by_Police_or_Magistrate_before_Trial_for_want_of_evidence_or_any_other_reason 56.939
# Persons_Trial_Completed 85.837
# Persons_under_Trial_at_Year_beginning 96.898
# Total_Persons_under_Trial 97.551

# %% [markdown]
# ## MODIFY FROM HERE

# %%
# Data to plot
labels = df["Sub_Group_Name"].unique()
sizes = df['Sub_Group_Name'].value_counts()
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','blue','yellow','purple', 'red','pink','grey','orange','darkblue']

plt.title('Type of Crime')

patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels,   bbox_to_anchor=(0.85,1.025), loc="upper left")
plt.subplots_adjust(left=0.05, bottom=0.1, right=0.75)
plt.axis('equal')
plt.show()

# %% [markdown]
# No bias in data. All type of Crime are equally represented for the respective States.

# %%
#Bar graph for cases acquitted versus cases convicted over years 2001 - 2010
xlabels = df["Sub_Group_Name"].unique()
print(df["Sub_Group_Name"].unique())

x1=df.groupby(["Sub_Group_Name"]).agg({'Cases_Acquitted_or_Discharged':'sum','Cases_Convicted':'sum'})
print(x1.head(50))
n=len(df["Sub_Group_Name"].unique())
r = np.arange(n)
width = 0.25
plt.bar(r,x1['Cases_Acquitted_or_Discharged'],color = 'b',width = width, edgecolor = 'black')
plt.bar(r + width, x1['Cases_Convicted'], color = 'g',width = width, edgecolor = 'black')
plt.xlabel("Crime")
plt.ylabel("No. of Cases")
plt.title("cases acquitted versus cases convicted over years 2001 - 2010")
plt.show()
# Out:
# ['01. Rape' '02. Kidnapping & Abduction of Women & Girls'
#  '03. Dowry Deaths' '04. Molestation' '05. Sexual Harassment'
#  '06. Cruelty by Husband and Relatives' '07. Importation of Girls']
#                                              Cases_Acquitted_or_Discharged  \
# Sub_Group_Name
# 01. Rape                                                            100941
# 02. Kidnapping & Abduction of Women & Girls                          58648
# 03. Dowry Deaths                                                     37249
# 04. Molestation                                                     143444
# 05. Sexual Harassment                                                34353
# 06. Cruelty by Husband and Relatives                                244110
# 07. Importation of Girls                                               234
#
#                                              Cases_Convicted
# Sub_Group_Name
# 01. Rape                                               36006
# 02. Kidnapping & Abduction of Women & Girls            20821
# 03. Dowry Deaths                                       18492
# 04. Molestation                                        62730
# 05. Sexual Harassment                                  45202
# 06. Cruelty by Husband and Relatives                   63205
# 07. Importation of Girls                                  57

# %%
plt.scatter(df['Cases_Reported'], df['Cases_Sent_for_Trial'], 
            color = '#A90303', marker = '*',alpha = 0.6,
             edgecolors = '#A4F5AF')

# %% [markdown]
# FINDING CORRELATION

# %%
sns.heatmap(df.corr(method='pearson'))
plt.savefig('heatmap.png')

# %%
#describe() funtion gives us the summary statistics of the dataframe
df.describe()
# Out:
#               Year  Cases_Acquitted_or_Discharged  \
# count  2450.000000                    2450.000000
# mean   2005.500000                     252.644490
# std       2.872868                     534.023365
# min    2001.000000                       0.000000
# 25%    2003.000000                       0.000000
# 50%    2005.500000                      17.000000
# 75%    2008.000000                     286.000000
# max    2010.000000                    5343.000000
#
#        Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# count                                        2450.000000
# mean                                           40.437143
# std                                           127.779987
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             4.000000
# 75%                                            24.000000
# max                                          1816.000000
#
#        Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# count          2450.000000                    2450.000000      2450.000000
# mean            527.591020                      54.545306       100.617551
# std            1215.994292                     242.164162       266.706351
# min               0.000000                       0.000000         0.000000
# 25%               1.000000                       0.000000         0.000000
# 50%              45.000000                       0.000000         8.000000
# 75%             507.750000                       8.000000        75.000000
# max           16946.000000                    3400.000000      3024.000000
#
#        Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# count                                        2450.000000
# mean                                           61.798367
# std                                           247.936275
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                            25.000000
# max                                          4755.000000
#
#        Cases_Investigated_Chargesheets+FR_Submitted  \
# count                                   2450.000000
# mean                                     568.028163
# std                                     1273.335949
# min                                        0.000000
# 25%                                        2.000000
# 50%                                       53.500000
# 75%                                      581.750000
# max                                    17407.000000
#
#        Cases_not_Investigated_or_in_which_investigation_was_refused  \
# count                                        2450.000000
# mean                                            1.062041
# std                                             4.965482
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            68.000000
#
#        Cases_Pending_Investigation_at_Year_End  ...  Cases_Trials_Completed  \
# count                              2450.000000  ...             2450.000000
# mean                                221.587347  ...              353.262041
# std                                 586.690003  ...              714.861052
# min                                   0.000000  ...                0.000000
# 25%                                   1.000000  ...                0.000000
# 50%                                  21.000000  ...               29.000000
# 75%                                 150.750000  ...              385.000000
# max                                8934.000000  ...             6099.000000
#
#        Cases_Withdrawn_by_the_Govt  \
# count                  2450.000000
# mean                      0.402857
# std                       8.120051
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                     306.000000
#
#        Cases_withdrawn_by_the_Govt_during_investigation  \
# count                                       2450.000000
# mean                                           0.278367
# std                                            2.954684
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                           72.000000
#
#        Total_Cases_for_Trial  Persons_Acquitted  \
# count            2450.000000        2450.000000
# mean             2440.475918         520.448980
# std              6074.949556        1380.104545
# min                 0.000000           0.000000
# 25%                 5.000000           0.000000
# 50%               207.000000          32.000000
# 75%              2170.000000         505.000000
# max             81124.000000       18221.000000
#
#        Persons_against_whom_cases_Compounded_or_Withdrawn  Persons_Arrested  \
# count                                        2450.000000        2450.000000
# mean                                           98.006531        1081.744898
# std                                           417.943070        2894.465173
# min                                             0.000000           0.000000
# 25%                                             0.000000           2.000000
# 50%                                             0.000000          76.000000
# 75%                                            14.000000         943.000000
# max                                          6870.000000       31807.000000
#
#        Persons_Chargesheeted  Persons_Convicted  \
# count            2450.000000        2450.000000
# mean             1008.696735         189.949388
# std              2706.244943         625.592904
# min                 0.000000           0.000000
# 25%                 1.000000           0.000000
# 50%                64.500000          11.000000
# 75%               871.750000         129.000000
# max             28238.000000       11741.000000
#
#        Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning
# count                                        2450.000000
# mean                                          231.892653
# std                                           656.112955
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            13.000000
# 75%                                           140.000000
# max                                          7616.000000
#
# [8 rows x 25 columns]

# %%
#correlation matrix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
#plt.savefig('result.png')
# Out:
# <style type="text/css">
# #T_f6572_row0_col0, #T_f6572_row1_col1, #T_f6572_row2_col2, #T_f6572_row3_col3, #T_f6572_row3_col14, #T_f6572_row4_col4, #T_f6572_row5_col5, #T_f6572_row6_col6, #T_f6572_row7_col7, #T_f6572_row8_col8, #T_f6572_row9_col9, #T_f6572_row10_col10, #T_f6572_row11_col11, #T_f6572_row11_col12, #T_f6572_row12_col11, #T_f6572_row12_col12, #T_f6572_row13_col13, #T_f6572_row14_col3, #T_f6572_row14_col14, #T_f6572_row15_col15, #T_f6572_row16_col16, #T_f6572_row17_col17, #T_f6572_row18_col18, #T_f6572_row19_col19, #T_f6572_row20_col20, #T_f6572_row21_col21, #T_f6572_row22_col22, #T_f6572_row23_col23, #T_f6572_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col1, #T_f6572_row8_col5, #T_f6572_row16_col4, #T_f6572_row16_col17, #T_f6572_row17_col21, #T_f6572_row23_col16 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col2, #T_f6572_row1_col17, #T_f6572_row8_col20, #T_f6572_row15_col17 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col3, #T_f6572_row0_col14, #T_f6572_row0_col18, #T_f6572_row0_col19, #T_f6572_row0_col22, #T_f6572_row1_col16, #T_f6572_row3_col16, #T_f6572_row7_col16, #T_f6572_row12_col16, #T_f6572_row13_col16, #T_f6572_row14_col16, #T_f6572_row18_col16, #T_f6572_row19_col17, #T_f6572_row21_col17 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col4, #T_f6572_row0_col5, #T_f6572_row0_col8, #T_f6572_row0_col16, #T_f6572_row0_col20, #T_f6572_row8_col0, #T_f6572_row16_col1, #T_f6572_row16_col2, #T_f6572_row16_col3, #T_f6572_row16_col6, #T_f6572_row16_col7, #T_f6572_row16_col9, #T_f6572_row16_col10, #T_f6572_row16_col11, #T_f6572_row16_col12, #T_f6572_row16_col13, #T_f6572_row16_col14, #T_f6572_row16_col15, #T_f6572_row16_col18, #T_f6572_row16_col19, #T_f6572_row16_col21, #T_f6572_row16_col22, #T_f6572_row16_col23, #T_f6572_row16_col24, #T_f6572_row17_col23, #T_f6572_row17_col24, #T_f6572_row24_col17 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col6, #T_f6572_row16_col5, #T_f6572_row17_col16, #T_f6572_row17_col19, #T_f6572_row17_col22 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col7, #T_f6572_row0_col11, #T_f6572_row4_col16, #T_f6572_row11_col17, #T_f6572_row12_col17, #T_f6572_row17_col1, #T_f6572_row17_col6, #T_f6572_row22_col17 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col9, #T_f6572_row7_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col10, #T_f6572_row2_col0, #T_f6572_row3_col0, #T_f6572_row11_col0, #T_f6572_row14_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col12, #T_f6572_row11_col16, #T_f6572_row17_col5, #T_f6572_row17_col15, #T_f6572_row20_col16 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col13, #T_f6572_row5_col16, #T_f6572_row5_col17, #T_f6572_row6_col17, #T_f6572_row18_col17 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col15, #T_f6572_row0_col17, #T_f6572_row2_col16, #T_f6572_row8_col16, #T_f6572_row8_col23, #T_f6572_row10_col16, #T_f6572_row16_col20, #T_f6572_row24_col16 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col21, #T_f6572_row15_col16, #T_f6572_row17_col3, #T_f6572_row17_col14, #T_f6572_row17_col20 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col23, #T_f6572_row17_col18, #T_f6572_row21_col16, #T_f6572_row22_col16, #T_f6572_row23_col17 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_f6572_row0_col24, #T_f6572_row8_col11, #T_f6572_row17_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col0, #T_f6572_row21_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_f6572_row1_col3, #T_f6572_row1_col14, #T_f6572_row3_col1, #T_f6572_row3_col15, #T_f6572_row14_col1, #T_f6572_row14_col15, #T_f6572_row15_col3, #T_f6572_row15_col14 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col4, #T_f6572_row1_col24, #T_f6572_row4_col13, #T_f6572_row18_col24 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_f6572_row1_col5, #T_f6572_row10_col1, #T_f6572_row12_col9, #T_f6572_row12_col10, #T_f6572_row19_col4, #T_f6572_row21_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_f6572_row1_col6, #T_f6572_row6_col20 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f6572_row1_col7, #T_f6572_row7_col1, #T_f6572_row7_col22, #T_f6572_row22_col7 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f6572_row1_col9, #T_f6572_row2_col21, #T_f6572_row5_col1, #T_f6572_row20_col23 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_f6572_row1_col10, #T_f6572_row4_col18, #T_f6572_row9_col11, #T_f6572_row9_col18, #T_f6572_row10_col11, #T_f6572_row10_col18, #T_f6572_row20_col11 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_f6572_row1_col11, #T_f6572_row11_col1, #T_f6572_row11_col21, #T_f6572_row21_col11 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col12, #T_f6572_row9_col24, #T_f6572_row12_col1, #T_f6572_row12_col13, #T_f6572_row13_col12, #T_f6572_row24_col9 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col13, #T_f6572_row3_col12, #T_f6572_row12_col3, #T_f6572_row12_col14, #T_f6572_row13_col1, #T_f6572_row13_col18, #T_f6572_row14_col12, #T_f6572_row18_col13 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col15, #T_f6572_row15_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col18, #T_f6572_row18_col1, #T_f6572_row21_col15 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col19, #T_f6572_row3_col18, #T_f6572_row14_col18, #T_f6572_row18_col3, #T_f6572_row18_col14, #T_f6572_row19_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col20, #T_f6572_row20_col1, #T_f6572_row20_col13, #T_f6572_row24_col13 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_f6572_row1_col21, #T_f6572_row13_col21, #T_f6572_row15_col22, #T_f6572_row21_col1, #T_f6572_row21_col3, #T_f6572_row21_col14 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col22, #T_f6572_row3_col22, #T_f6572_row14_col22, #T_f6572_row15_col13 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_f6572_row1_col23, #T_f6572_row15_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f6572_row2_col1, #T_f6572_row23_col11 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f6572_row2_col3, #T_f6572_row2_col14, #T_f6572_row5_col6, #T_f6572_row5_col11, #T_f6572_row19_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_f6572_row2_col4, #T_f6572_row5_col10, #T_f6572_row23_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_f6572_row2_col5 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f6572_row2_col6, #T_f6572_row2_col18 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_f6572_row2_col7, #T_f6572_row2_col9, #T_f6572_row9_col2, #T_f6572_row23_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f6572_row2_col8, #T_f6572_row6_col8, #T_f6572_row10_col17, #T_f6572_row17_col10 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f6572_row2_col10, #T_f6572_row10_col2, #T_f6572_row19_col23 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f6572_row2_col11 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_f6572_row2_col12, #T_f6572_row6_col11, #T_f6572_row24_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f6572_row2_col13, #T_f6572_row4_col11, #T_f6572_row7_col2, #T_f6572_row9_col22, #T_f6572_row23_col19 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f6572_row2_col15 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f6572_row2_col17, #T_f6572_row17_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_f6572_row2_col19, #T_f6572_row6_col4, #T_f6572_row23_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f6572_row2_col20, #T_f6572_row11_col6, #T_f6572_row12_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_f6572_row2_col22, #T_f6572_row

# %%
strong_corr = df.corr().round(6).unstack()
strong_corr = strong_corr[abs(strong_corr) >= 0.9]
strong_corr = strong_corr.sort_values(ascending=False)
strong_df= strong_corr.to_frame().reset_index()
strong_df
# Out:
#                                            level_0  \
# 0                                             Year
# 1     Cases_Investigated_Chargesheets+FR_Submitted
# 2          Cases_Pending_Investigation_at_Year_End
# 3   Cases_Pending_Investigation_from_previous_year
# 4                  Cases_Pending_Trial_at_Year_End
# ..                                             ...
# 72                             Cases_Chargesheeted
# 73    Cases_Investigated_Chargesheets+FR_Submitted
# 74                   Cases_Acquitted_or_Discharged
# 75                           Persons_Chargesheeted
# 76    Cases_Investigated_Chargesheets+FR_Submitted
#
#                                            level_1         0
# 0                                             Year  1.000000
# 1     Cases_Investigated_Chargesheets+FR_Submitted  1.000000
# 2          Cases_Pending_Investigation_at_Year_End  1.000000
# 3   Cases_Pending_Investigation_from_previous_year  1.000000
# 4                  Cases_Pending_Trial_at_Year_End  1.000000
# ..                                             ...       ...
# 72                   Cases_Acquitted_or_Discharged  0.907581
# 73                   Cases_Acquitted_or_Discharged  0.903435
# 74    Cases_Investigated_Chargesheets+FR_Submitted  0.903435
# 75    Cases_Investigated_Chargesheets+FR_Submitted  0.902532
# 76                           Persons_Chargesheeted  0.902532
#
# [77 rows x 3 columns]

# %%
strong_df = strong_df[strong_df.level_0!=strong_df.level_1]
m = pd.DataFrame(np.sort(strong_df[['level_0','level_1']], axis=1), index=strong_df.index).duplicated()
strong_df = strong_df[~m]
strong_df = strong_df.reset_index(drop=True)
strong_df
# Out:
#                                            level_0  \
# 0                             Cases_Sent_for_Trial
# 1                  Cases_Pending_Trial_at_Year_End
# 2                              Cases_Chargesheeted
# 3     Cases_Investigated_Chargesheets+FR_Submitted
# 4                            Total_Cases_for_Trial
# 5                            Total_Cases_for_Trial
# 6                                 Persons_Arrested
# 7                                   Cases_Reported
# 8   Cases_Pending_Investigation_from_previous_year
# 9                             Cases_Sent_for_Trial
# 10                             Cases_Chargesheeted
# 11                           Persons_Chargesheeted
# 12                   Cases_Acquitted_or_Discharged
# 13                               Persons_Acquitted
# 14                   Cases_Compounded_or_Withdrawn
# 15                            Cases_Sent_for_Trial
# 16                           Total_Cases_for_Trial
# 17                               Persons_Acquitted
# 18                           Total_Cases_for_Trial
# 19    Cases_Investigated_Chargesheets+FR_Submitted
# 20                          Cases_Trials_Completed
# 21                          Cases_Trials_Completed
# 22                   Cases_Acquitted_or_Discharged
# 23                            Cases_Sent_for_Trial
# 24    Cases_Investigated_Chargesheets+FR_Submitted
# 25                           Persons_Chargesheeted
#
#                                               level_1         0
# 0                                 Cases_Chargesheeted  1.000000
# 1          Cases_Pending_Trial_from_the_previous_year  0.997452
# 2        Cases_Investigated_Chargesheets+FR_Submitted  0.995789
# 3                                Cases_Sent_for_Trial  0.995789
# 4          Cases_Pending_Trial_from_the_previous_year  0.995713
# 5                     Cases_Pending_Trial_at_Year_End  0.995146
# 6                               Persons_Chargesheeted  0.993084
# 7        Cases_Investigated_Chargesheets+FR_Submitted  0.985869
# 8             Cases_Pending_Investigation_at_Year_End  0.981443
# 9                                      Cases_Reported  0.979532
# 10                                     Cases_Reported  0.979532
# 11                                  Persons_Acquitted  0.956357
# 12                             Cases_Trials_Completed  0.949666
# 13                                   Persons_Arrested  0.943320
# 14  Persons_against_whom_cases_Compounded_or_Withd...  0.928256
# 15                              Total_Cases_for_Trial  0.925765
# 16                                Cases_Chargesheeted  0.925765
# 17                      Cases_Acquitted_or_Discharged  0.925491
# 18       Cases_Investigated_Chargesheets+FR_Submitted  0.916149
# 19                             Cases_Trials_Completed  0.912846
# 20                               Cases_Sent_for_Trial  0.908630
# 21                                Cases_Chargesheeted  0.908630
# 22                                Cases_Chargesheeted  0.907581
# 23                      Cases_Acquitted_or_Discharged  0.907581
# 24                      Cases_Acquitted_or_Discharged  0.903435
# 25       Cases_Investigated_Chargesheets+FR_Submitted  0.902532

# %%
#Outlier Analysis
sns.boxplot(x=df['Total_Cases_for_Trial'])
# Out:
# <AxesSubplot: xlabel='Total_Cases_for_Trial'>

# %% [markdown]
# Since the total cases for trial are outliers, we have to drop those set of rpws which are a cumulation of all the cases for trial.

# %%
# # Scatter plot
# fig, ax = plt.subplots(figsize = (5,5))
# ax.scatter(df['Total_Persons_under_Trial'],df['Persons_Trial_Completed'])
 
# # x-axis label
# ax.set_xlabel('Total Persons under trial')
 
# # y-axis label
# ax.set_ylabel('Persons whose trial is completed')
# plt.show()

# %%
# fig, ax = plt.subplots(figsize = (5,5))
# ax.scatter(df['Cases_Trials_Completed'],df['Total_Cases_for_Trial'])
 
# # x-axis label
# ax.set_xlabel('Total cases for trial')
 
# # y-axis label
# ax.set_ylabel('Cases completed')
# plt.show()

# %%
# #z-score
# from scipy import stats
 
# z = np.abs(stats.zscore(df['Cases_Acquitted_or_Discharged']))
# print(z)

# %%
# sns.regplot(x=df["Cases_Trials_Completed"], y=df["Total_Cases_for_Trial"])

# %%
x=df.groupby(["Sub_Group_Name","Year"]).agg({'Cases_Reported':'sum'}).reset_index()
xlbs = list(df["Year"].unique())
#print(xlbs)

xgraph=x.loc[x['Sub_Group_Name'] == "01. Rape"]
xgraph2=x.loc[x['Sub_Group_Name'] == "02. Kidnapping & Abduction of Women & Girls"]
xgraph3=x.loc[x['Sub_Group_Name'] == "03. Dowry Deaths"]
xgraph4=x.loc[x['Sub_Group_Name'] == "04. Molestation"]
xgraph5=x.loc[x['Sub_Group_Name'] == "05. Sexual Harassment"]
xgraph6=x.loc[x['Sub_Group_Name'] == "06. Cruelty by Husband and Relatives"]
xgraph7=x.loc[x['Sub_Group_Name'] == "07. Importation of Girls"]

crimes = df["Sub_Group_Name"].unique()
#print(xgraph["Cases_Reported"])
r=np.arange(10) 
plt.plot(r, xgraph["Cases_Reported"], color='r')
plt.plot(r, xgraph2["Cases_Reported"], color='b')
plt.plot(r, xgraph3["Cases_Reported"], color='y')
plt.plot(r, xgraph5["Cases_Reported"], color='brown')

plt.xlabel("Years")
plt.ylabel("Number of Cases Reported")
plt.gca().legend(('Rape','Kidnapping','Dowry Deaths','Sexual Harassment','Cruelty'),bbox_to_anchor=(1.05,1.025), loc="upper left")
plt.xticks(np.arange(10), xlbs)  

plt.show()

# %%
plt.plot(r, xgraph4["Cases_Reported"], color='orange')
plt.plot(r, xgraph6["Cases_Reported"], color='green')
plt.xticks(np.arange(10), xlbs) 
plt.gca().legend(('Molestation','Cruelty by Husband and Relatives'),bbox_to_anchor=(1.05,1.025), loc="upper left")
plt.xlabel("Years")
plt.ylabel("Number of Cases Reported")
plt.show()

# %%
crime = list(df["Sub_Group_Name"].unique())[0:]
crime
# Out:
# ['01. Rape',
#  '02. Kidnapping & Abduction of Women & Girls',
#  '03. Dowry Deaths',
#  '04. Molestation',
#  '05. Sexual Harassment',
#  '06. Cruelty by Husband and Relatives',
#  '07. Importation of Girls']

# %%
g= pd.DataFrame(df.groupby(['Sub_Group_Name'])['Cases_Reported'].sum().reset_index())
g = g.sort_values("Cases_Reported",ascending = False)
g
# Out:
#                                 Sub_Group_Name  Cases_Reported
# 5         06. Cruelty by Husband and Relatives          669539
# 3                              04. Molestation          364836
# 1  02. Kidnapping & Abduction of Women & Girls          190080
# 0                                     01. Rape          190008
# 4                        05. Sexual Harassment          106311
# 2                             03. Dowry Deaths           74351
# 6                     07. Importation of Girls             753

# %%
fig= px.bar(g,x=df['Sub_Group_Name'],y=df['Cases_Reported'],color_discrete_sequence=['blue'])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Python\DA Project\Final_Code_Vi4_FINAL.ipynb Cell 42 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Python/DA%20Project/Final_Code_Vi4_FINAL.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> fig= px.bar(g,x=df['Sub_Group_Name'],y=df['Cases_Reported'],color_discrete_sequence=['blue'])
# ----> <a href='vscode-notebook-cell:/d%3A/Python/DA%20Project/Final_Code_Vi4_FINAL.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# File c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\basedatatypes.py:3398, in BaseFigure.show(self, *args, **kwargs)
#    3365 """
#    3366 Show a figure using either the default renderer(s) or the renderer(s)
#    3367 specified by the renderer argument
#    (...)
#    3394 None
#    3395 """
#    3396 import plotly.io as pio
# -> 3398 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
g= pd.DataFrame(df.groupby(['Year'])['Cases_Reported'].sum().reset_index())
g = g.sort_values("Cases_Reported",ascending = False)
g
# Out:
#    Year  Cases_Reported
# 9  2010          205009
# 8  2009          194835
# 7  2008          186616
# 6  2007          174921
# 5  2006          154158
# 3  2004          143615
# 4  2005          143523
# 2  2003          131364
# 1  2002          131112
# 0  2001          130725

# %%
fig= px.bar(g,x='Year',y='Cases_Reported',color_discrete_sequence=['blue'])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Python\DA Project\Final_Code_Vi4_FINAL.ipynb Cell 44 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Python/DA%20Project/Final_Code_Vi4_FINAL.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> fig= px.bar(g,x='Year',y='Cases_Reported',color_discrete_sequence=['blue'])
# ----> <a href='vscode-notebook-cell:/d%3A/Python/DA%20Project/Final_Code_Vi4_FINAL.ipynb#X61sZmlsZQ%3D%3D?line=1'>2</a> fig.show()
#
# File c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\basedatatypes.py:3398, in BaseFigure.show(self, *args, **kwargs)
#    3365 """
#    3366 Show a figure using either the default renderer(s) or the renderer(s)
#    3367 specified by the renderer argument
#    (...)
#    3394 None
#    3395 """
#    3396 import plotly.io as pio
# -> 3398 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
for i in crime:
  df_i = df[df['Sub_Group_Name']==i]
  gi= pd.DataFrame(df_i.groupby(['Area_Name'])['Cases_Reported'].sum().reset_index())
  gi =gi.sort_values("Cases_Reported",ascending = False)
  print(i)
  fig= px.bar(gi,x='Area_Name',y='Cases_Reported',color_discrete_sequence=['blue'])
  fig.show()
# Out:
# 01. Rape
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Python\DA Project\Final_Code_Vi4_FINAL.ipynb Cell 45 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/Python/DA%20Project/Final_Code_Vi4_FINAL.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> print(i)
#       <a href='vscode-notebook-cell:/d%3A/Python/DA%20Project/Final_Code_Vi4_FINAL.ipynb#X62sZmlsZQ%3D%3D?line=5'>6</a> fig= px.bar(gi,x='Area_Name',y='Cases_Reported',color_discrete_sequence=['blue'])
# ----> <a href='vscode-notebook-cell:/d%3A/Python/DA%20Project/Final_Code_Vi4_FINAL.ipynb#X62sZmlsZQ%3D%3D?line=6'>7</a> fig.show()
#
# File c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\basedatatypes.py:3398, in BaseFigure.show(self, *args, **kwargs)
#    3365 """
#    3366 Show a figure using either the default renderer(s) or the renderer(s)
#    3367 specified by the renderer argument
#    (...)
#    3394 None
#    3395 """
#    3396 import plotly.io as pio
# -> 3398 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# ## Models to predict Cases Reported

# %% [markdown]
# (Based on year, state, crime type)

# %% [markdown]
# ## 1. MLR  with dummy variables

# %%
df_en = df.copy(deep=True)
df_en
# Out:
#                       Area_Name  Year            Sub_Group_Name  \
# 0     Andaman & Nicobar Islands  2001                  01. Rape
# 1                Andhra Pradesh  2001                  01. Rape
# 2             Arunachal Pradesh  2001                  01. Rape
# 3                         Assam  2001                  01. Rape
# 4                         Bihar  2001                  01. Rape
# ...                         ...   ...                       ...
# 2445                 Tamil Nadu  2010  07. Importation of Girls
# 2446                    Tripura  2010  07. Importation of Girls
# 2447              Uttar Pradesh  2010  07. Importation of Girls
# 2448                Uttarakhand  2010  07. Importation of Girls
# 2449                West Bengal  2010  07. Importation of Girls
#
#       Cases_Acquitted_or_Discharged  \
# 0                                 5
# 1                               731
# 2                                 1
# 3                               334
# 4                               406
# ...                             ...
# 2445                              0
# 2446                              0
# 2447                              0
# 2448                              0
# 2449                              8
#
#       Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 0                                                     2
# 1                                                    22
# 2                                                     2
# 3                                                    95
# 4                                                   141
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#       Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# 0                       3                              0                0
# 1                     769                             35              197
# 2                      25                              0                2
# 3                     495                             10              101
# 4                     685                              0              155
# ...                   ...                            ...              ...
# 2445                    0                              0                0
# 2446                    0                              0                0
# 2447                    0                              0                0
# 2448                    0                              0                0
# 2449                    8                              0                0
#
#       Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# 0                                                     0
# 1                                                    74
# 2                                                     0
# 3                                                    45
# 4                                                   105
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#       Cases_Investigated_Chargesheets+FR_Submitted  ...  \
# 0                                                5  ...
# 1                                              791  ...
# 2                                               27  ...
# 3                                              590  ...
# 4                                              826  ...
# ...                                            ...  ...
# 2445                                             0  ...
# 2446                                             0  ...
# 2447                                             0  ...
# 2448                                             0  ...
# 2449                                             8  ...
#
#       Cases_Trials_Completed  Cases_Withdrawn_by_the_Govt  \
# 0                          5                            0
# 1                        928                            2
# 2                          3                            0
# 3                        435                            0
# 4                        561                            0
# ...                      ...                          ...
# 2445                       0                            0
# 2446                       0                            0
# 2447                       0                            0
# 2448                       0                            0
# 2449                       8                            0
#
#       Cases_withdrawn_by_the_Govt_during_investigation  Total_Cases_for_Trial  \
# 0                                                    0                     39
# 1                                                    0                   2937
# 2                                                    0                    285
# 3                                                    0                   2409
# 4                                                    0                   3746
# ...                                                ...                    ...
# 2445                                                 0                      0
# 2446                                                 0                      0
# 2447                                                 0                      0
# 2448                                                 0                      0
# 2449                                                 0                     26
#
#       Persons_Acquitted  Persons_against_whom_cases_Compounded_or_Withdrawn  \
# 0                     6                                                  0
# 1                  1168                                                 13
# 2                     1                                                  0
# 3                   403                                                 14
# 4                   756                                                  0
# ...                 ...                                                ...
# 2445                  0                                                  0
# 2446                  0                                                  0
# 2447                  0                                                  0
# 2448                  0                                                  0
# 2449                 19                                                  0
#
#       Persons_Arrested  Persons_Chargesheeted  Persons_Convicted  \
# 0                    3                      3                  0
# 1                 1150                   1021                246
# 2                   51                     31                  2
# 3                  928                    585                120
# 4                 1400                   1302                217
# ...                ...                    ...                ...
# 2445                 0                      0                  0
# 2446                 0                      0                  0
# 2447                 0                      0                  0
# 2448                 0                      0                  0
# 2449                11                      8                  0
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning
# 0                                                     6
# 1                                                   450
# 2                                                    25
# 3                                                   806
# 4                                                   719
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  4
#
# [2450 rows x 27 columns]

# %%
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
df_en['Area_Name']= label_encoder.fit_transform(df_en['Area_Name'])
df_en['Sub_Group_Name']= label_encoder.fit_transform(df_en['Sub_Group_Name'])
df_en
# Out:
#       Area_Name  Year  Sub_Group_Name  Cases_Acquitted_or_Discharged  \
# 0             0  2001               0                              5
# 1             1  2001               0                            731
# 2             2  2001               0                              1
# 3             3  2001               0                            334
# 4             4  2001               0                            406
# ...         ...   ...             ...                            ...
# 2445         30  2010               6                              0
# 2446         31  2010               6                              0
# 2447         32  2010               6                              0
# 2448         33  2010               6                              0
# 2449         34  2010               6                              8
#
#       Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 0                                                     2
# 1                                                    22
# 2                                                     2
# 3                                                    95
# 4                                                   141
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#       Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# 0                       3                              0                0
# 1                     769                             35              197
# 2                      25                              0                2
# 3                     495                             10              101
# 4                     685                              0              155
# ...                   ...                            ...              ...
# 2445                    0                              0                0
# 2446                    0                              0                0
# 2447                    0                              0                0
# 2448                    0                              0                0
# 2449                    8                              0                0
#
#       Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# 0                                                     0
# 1                                                    74
# 2                                                     0
# 3                                                    45
# 4                                                   105
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#       Cases_Investigated_Chargesheets+FR_Submitted  ...  \
# 0                                                5  ...
# 1                                              791  ...
# 2                                               27  ...
# 3                                              590  ...
# 4                                              826  ...
# ...                                            ...  ...
# 2445                                             0  ...
# 2446                                             0  ...
# 2447                                             0  ...
# 2448                                             0  ...
# 2449                                             8  ...
#
#       Cases_Trials_Completed  Cases_Withdrawn_by_the_Govt  \
# 0                          5                            0
# 1                        928                            2
# 2                          3                            0
# 3                        435                            0
# 4                        561                            0
# ...                      ...                          ...
# 2445                       0                            0
# 2446                       0                            0
# 2447                       0                            0
# 2448                       0                            0
# 2449                       8                            0
#
#       Cases_withdrawn_by_the_Govt_during_investigation  Total_Cases_for_Trial  \
# 0                                                    0                     39
# 1                                                    0                   2937
# 2                                                    0                    285
# 3                                                    0                   2409
# 4                                                    0                   3746
# ...                                                ...                    ...
# 2445                                                 0                      0
# 2446                                                 0                      0
# 2447                                                 0                      0
# 2448                                                 0                      0
# 2449                                                 0                     26
#
#       Persons_Acquitted  Persons_against_whom_cases_Compounded_or_Withdrawn  \
# 0                     6                                                  0
# 1                  1168                                                 13
# 2                     1                                                  0
# 3                   403                                                 14
# 4                   756                                                  0
# ...                 ...                                                ...
# 2445                  0                                                  0
# 2446                  0                                                  0
# 2447                  0                                                  0
# 2448                  0                                                  0
# 2449                 19                                                  0
#
#       Persons_Arrested  Persons_Chargesheeted  Persons_Convicted  \
# 0                    3                      3                  0
# 1                 1150                   1021                246
# 2                   51                     31                  2
# 3                  928                    585                120
# 4                 1400                   1302                217
# ...                ...                    ...                ...
# 2445                 0                      0                  0
# 2446                 0                      0                  0
# 2447                 0                      0                  0
# 2448                 0                      0                  0
# 2449                11                      8                  0
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning
# 0                                                     6
# 1                                                   450
# 2                                                    25
# 3                                                   806
# 4                                                   719
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  4
#
# [2450 rows x 27 columns]

# %%
#TRAINING DATA USING MLR
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

train_df, test = train_test_split(df_en, test_size=0.3, random_state=42, shuffle=True)
train_df
# Out:
#       Area_Name  Year  Sub_Group_Name  Cases_Acquitted_or_Discharged  \
# 519          29  2005               1                              0
# 308          28  2009               0                            385
# 2032          2  2009               5                              3
# 2108          8  2001               6                              0
# 873          33  2005               2                             29
# ...         ...   ...             ...                            ...
# 1638         28  2007               4                              7
# 1095         10  2002               3                              7
# 1130         10  2003               3                             10
# 1294         34  2007               3                            611
# 860          20  2005               2                            266
#
#       Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 519                                                   0
# 308                                                  13
# 2032                                                  0
# 2108                                                  0
# 873                                                  14
# ...                                                 ...
# 1638                                                  0
# 1095                                                  1
# 1130                                                  3
# 1294                                                 92
# 860                                                   2
#
#       Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# 519                     2                              0                0
# 308                   967                             14              221
# 2032                   14                              0                3
# 2108                    0                              0                0
# 873                    48                              0               14
# ...                   ...                            ...              ...
# 1638                   19                              2               14
# 1095                   14                              2                6
# 1130                   11                              3                2
# 1294                 1585                              6               87
# 860                   336                              2               34
#
#       Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# 519                                                   0
# 308                                                 518
# 2032                                                  0
# 2108                                                  0
# 873                                                   2
# ...                                                 ...
# 1638                                                  7
# 1095                                                  0
# 1130                                                  0
# 1294                                                  2
# 860                                                   1
#
#       Cases_Investigated_Chargesheets+FR_Submitted  ...  \
# 519                                              2  ...
# 308                                            980  ...
# 2032                                            14  ...
# 2108                                             0  ...
# 873                                             62  ...
# ...                                            ...  ...
# 1638                                            19  ...
# 1095                                            15  ...
# 1130                                            14  ...
# 1294                                          1677  ...
# 860                                            338  ...
#
#       Cases_Trials_Completed  Cases_Withdrawn_by_the_Govt  \
# 519                        0                            0
# 308                      606                            0
# 2032                       6                            0
# 2108                       0                            0
# 873                       43                            0
# ...                      ...                          ...
# 1638                      21                            3
# 1095                      13                            0
# 1130                      12                            0
# 1294                     698                            0
# 860                      300                            0
#
#       Cases_withdrawn_by_the_Govt_during_investigation  Total_Cases_for_Trial  \
# 519                                                  0                      5
# 308                                                  0                   3150
# 2032                                                 0                     87
# 2108                                                 0                      0
# 873                                                  0                    248
# ...                                                ...                    ...
# 1638                                                 0                    124
# 1095                                                 0                     57
# 1130                                                 0                     53
# 1294                                                 0                   9098
# 860                                                  0                   3341
#
#       Persons_Acquitted  Persons_against_whom_cases_Compounded_or_Withdrawn  \
# 519                   0                                                  0
# 308                 545                                                 23
# 2032                  4                                                  0
# 2108                  0                                                  0
# 873                  84                                                  0
# ...                 ...                                                ...
# 1638                 15                                                  6
# 1095                 16                                                  3
# 1130                 13                                                  3
# 1294                804                                                 31
# 860                 792                                                  2
#
#       Persons_Arrested  Persons_Chargesheeted  Persons_Convicted  \
# 519                  3                      1                  0
# 308               1388                   1387                296
# 2032                12                     14                  3
# 2108                 0                      0                  0
# 873                160                    135                 43
# ...                ...                    ...                ...
# 1638                34                     34                 15
# 1095                24                     21                  7
# 1130                15                     13                  3
# 1294              1712                   1839                 87
# 860               1379                   1315                 72
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning
# 519                                                   0
# 308                                                  12
# 2032                                                  4
# 2108                                                  0
# 873                                                  50
# ...                                                 ...
# 1638                                                  0
# 1095                                                  5
# 1130                                                  7
# 1294                                               1161
# 860                                                 182
#
# [1715 rows x 27 columns]

# %%
x= train_df[["Year","Area_Name","Sub_Group_Name","Cases_Sent_for_Trial"]]
y = train_df['Cases_Reported']

regr = linear_model.LinearRegression()
model = regr.fit(x,y)
r_sq = model.score(x, y)
r_sq

y_pred = model.predict(x)
y_pred
mse = mean_squared_error(y,y_pred)
mse**0.5
# Out:
# 282.6459977981301

# %%
mx=df["Cases_Reported"].max()
#print(mx)
mn=df['Cases_Reported'].min()
#print(mn)
normalised_rmse=(mse**0.5)/(mx-mn)
print("Normalised RMSE for MLR: ",normalised_rmse)
# Out:
# Normalised RMSE for MLR:  0.01588255775444651

# %% [markdown]
# The Multiple Regression model above uses the year, area, type of crime and the cases that are sent for trial to perform the prdictions for the number of cases reported. We decided to try this model due to the high correlation between the repective features found in the EDA performed above

# %% [markdown]
# ## 2. RANDOM FOREST 1
# ### Label Encoder Version to predict Cases Reported

# %%
#CREATING DUMMY VARIABLES
X = df.iloc[:, :].values
print(X)
# Out:
# [['Andaman & Nicobar Islands' 2001 '01. Rape' ... 3 0 6]
#  ['Andhra Pradesh' 2001 '01. Rape' ... 1021 246 450]
#  ['Arunachal Pradesh' 2001 '01. Rape' ... 31 2 25]
#  ...
#  ['Uttar Pradesh' 2010 '07. Importation of Girls' ... 0 0 0]
#  ['Uttarakhand' 2010 '07. Importation of Girls' ... 0 0 0]
#  ['West Bengal' 2010 '07. Importation of Girls' ... 8 0 4]]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
#encoding Area_Name 
X[:,0] = labelencoder_X.fit_transform(X[:,0])
#encoding Sub_Group_Name
X[:,2] = labelencoder_X.fit_transform(X[:,2])
print(X)
# Out:
# [[0 2001 0 ... 3 0 6]
#  [1 2001 0 ... 1021 246 450]
#  [2 2001 0 ... 31 2 25]
#  ...
#  [32 2010 6 ... 0 0 0]
#  [33 2010 6 ... 0 0 0]
#  [34 2010 6 ... 8 0 4]]

# %%
#NEW DF WITH ONLY 4 REQUIRED COLUMNS
df_Lencoded=pd.DataFrame(X,columns=df.columns)
df_Lencoded
# Out:
#      Area_Name  Year Sub_Group_Name Cases_Acquitted_or_Discharged  \
# 0            0  2001              0                             5
# 1            1  2001              0                           731
# 2            2  2001              0                             1
# 3            3  2001              0                           334
# 4            4  2001              0                           406
# ...        ...   ...            ...                           ...
# 2445        30  2010              6                             0
# 2446        31  2010              6                             0
# 2447        32  2010              6                             0
# 2448        33  2010              6                             0
# 2449        34  2010              6                             8
#
#      Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 0                                                     2
# 1                                                    22
# 2                                                     2
# 3                                                    95
# 4                                                   141
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#      Cases_Chargesheeted Cases_Compounded_or_Withdrawn Cases_Convicted  \
# 0                      3                             0               0
# 1                    769                            35             197
# 2                     25                             0               2
# 3                    495                            10             101
# 4                    685                             0             155
# ...                  ...                           ...             ...
# 2445                   0                             0               0
# 2446                   0                             0               0
# 2447                   0                             0               0
# 2448                   0                             0               0
# 2449                   8                             0               0
#
#      Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# 0                                                     0
# 1                                                    74
# 2                                                     0
# 3                                                    45
# 4                                                   105
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#      Cases_Investigated_Chargesheets+FR_Submitted  ... Cases_Trials_Completed  \
# 0                                               5  ...                      5
# 1                                             791  ...                    928
# 2                                              27  ...                      3
# 3                                             590  ...                    435
# 4                                             826  ...                    561
# ...                                           ...  ...                    ...
# 2445                                            0  ...                      0
# 2446                                            0  ...                      0
# 2447                                            0  ...                      0
# 2448                                            0  ...                      0
# 2449                                            8  ...                      8
#
#      Cases_Withdrawn_by_the_Govt  \
# 0                              0
# 1                              2
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 2445                           0
# 2446                           0
# 2447                           0
# 2448                           0
# 2449                           0
#
#      Cases_withdrawn_by_the_Govt_during_investigation Total_Cases_for_Trial  \
# 0                                                   0                    39
# 1                                                   0                  2937
# 2                                                   0                   285
# 3                                                   0                  2409
# 4                                                   0                  3746
# ...                                               ...                   ...
# 2445                                                0                     0
# 2446                                                0                     0
# 2447                                                0                     0
# 2448                                                0                     0
# 2449                                                0                    26
#
#      Persons_Acquitted Persons_against_whom_cases_Compounded_or_Withdrawn  \
# 0                    6                                                  0
# 1                 1168                                                 13
# 2                    1                                                  0
# 3                  403                                                 14
# 4                  756                                                  0
# ...                ...                                                ...
# 2445                 0                                                  0
# 2446                 0                                                  0
# 2447                 0                                                  0
# 2448                 0                                                  0
# 2449                19                                                  0
#
#      Persons_Arrested Persons_Chargesheeted Persons_Convicted  \
# 0                   3                     3                 0
# 1                1150                  1021               246
# 2                  51                    31                 2
# 3                 928                   585               120
# 4                1400                  1302               217
# ...               ...                   ...               ...
# 2445                0                     0                 0
# 2446                0                     0                 0
# 2447                0                     0                 0
# 2448                0                     0                 0
# 2449               11                     8                 0
#
#      Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning
# 0                                                     6
# 1                                                   450
# 2                                                    25
# 3                                                   806
# 4                                                   719
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  4
#
# [2450 rows x 27 columns]

# %%
df_rf = df_Lencoded[["Area_Name","Year","Sub_Group_Name","Cases_Reported"]]

# %%
# Labels are the values we want to predict
labels = np.array(df_rf['Cases_Reported'])
# Remove the labels from the features
# axis 1 refers to the columns
df_rf_train= df_rf.drop('Cases_Reported', axis = 1)
# Saving feature names for later use
df_list = list(df_rf.columns)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(df_rf_train, labels, test_size = 0.1, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (2205, 3)
# Training Labels Shape: (2205,)
# Testing Features Shape: (245, 3)
# Testing Labels Shape: (245,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

# %%
np.set_printoptions(suppress=True,formatter={'float_kind':'{:.2f}'.format})
predictions
# Out:
# array([1367.18, 115.80, 0.06, 641.93, 579.28, 0.83, 20.12, 10612.15,
#        1811.40, 58.21, 9.59, 30.32, 3.12, 1332.32, 383.45, 740.26,
#        2249.51, 935.29, 1.46, 201.49, 1894.00, 1058.20, 1795.70, 930.02,
#        0.45, 1090.83, 1525.75, 1442.74, 44.06, 40.74, 50.06, 36.03,
#        727.91, 27.87, 0.14, 3508.13, 0.09, 672.95, 40.86, 549.76, 0.13,
#        4.35, 1036.55, 4.56, 789.68, 19.16, 146.57, 181.28, 6611.21,
#        598.00, 0.00, 56.44, 440.74, 0.06, 1629.45, 223.04, 454.78, 883.22,
#        1256.71, 40.42, 983.38, 0.01, 81.90, 34.77, 307.64, 44.03, 2317.19,
#        933.21, 22.62, 352.80, 61.35, 0.04, 349.48, 8.51, 117.21, 1754.54,
#        0.00, 1386.03, 21.78, 150.40, 0.12, 2589.77, 80.91, 925.40,
#        1556.74, 0.71, 4821.55, 1.59, 46.73, 42.43, 931.97, 7.41, 818.42,
#        424.52, 0.03, 238.40, 781.57, 6.20, 35.91, 0.44, 601.18, 53.42,
#        29.62, 833.12, 1958.95, 34.59, 543.36, 6.48, 0.01, 135.21, 22.52,
#        39.87, 17.26, 282.56, 1584.47, 639.50, 2726.13, 864.54, 970.15,
#        1.84, 116.09, 110.83, 128.06, 0.31, 63.30, 389.84, 3697.59, 759.09,
#        529.28, 56.30, 8827.48, 243.50, 11.92, 5609.92, 1.44, 678.39, 5.34,
#        55.75, 0.27, 1.77, 18.34, 1186.78, 933.36, 1098.17, 21.61, 262.38,
#        1562.71, 1686.55, 808.25, 6.60, 7.59, 2.19, 739.18, 5.96, 959.06,
#        0.05, 504.66, 266.56, 5.54, 0.50, 1109.37, 1328.29, 1835.66, 21.40,
#        109.91, 2.92, 4220.24, 0.41, 548.11, 0.52, 53.91, 0.13, 577.33,
#        5.02, 256.25, 31.15, 2.46, 14.22, 0.42, 1236.92, 0.00, 0.12, 69.79,
#        0.23, 231.42, 269.94, 2.09, 4766.63, 14.36, 159.96, 1365.15, 27.94,
#        5.22, 2973.69, 23.73, 9.00, 0.27, 2013.45, 105.69, 1063.43, 0.17,
#        11.02, 39.95, 879.31, 54.40, 38.22, 108.57, 2770.36, 3077.38,
#        507.94, 7.22, 1207.54, 391.95, 95.35, 501.73, 2147.05, 20.18,
#        5420.27, 0.00, 2736.10, 1450.59, 92.24, 162.03, 0.00, 0.46, 1.14,
#        251.37, 198.31, 0.04, 30.63, 6.49, 6908.61, 975.65, 7.83, 1.81,
#        49.02, 8.74, 2.45, 28.90, 6.67, 121.09, 254.65, 5.90, 0.56, 656.70])

# %%
errors = abs(predictions - test_labels)
print('Mean Absolute Error:', round(np.mean(errors), 2))
# Out:
# Mean Absolute Error: 86.8

# %% [markdown]
# MAPE (Mean Absolute Percentage Error) cannot be calculated as values in the dataset are 0 and hence, MAPE will give "division by zero" error.

# %%
from sklearn.metrics import mean_squared_error
MSE_error_rf1 = mean_squared_error(test_labels, predictions)
print('Root Mean Squared Error:',round((MSE_error_rf1**.5),2))
# Out:
# Root Mean Squared Error: 199.3

# %%
mx=df["Cases_Reported"].max()
#print(mx)
mn=df['Cases_Reported'].min()
#print(mn)
normalised_rmse=(MSE_error_rf1**0.5)/(mx-mn)
print("Normalised RMSE for Random Forest 1: ",normalised_rmse)
# Out:
# Normalised RMSE for Random Forest 1:  0.011199276745165933

# %% [markdown]
# RMSE tends to penalise the larger error to a greate magnitude

# %% [markdown]
# ## 3. RANDOM FOREST 2
# ### One-Hot Encoding Version to predict Cases Reported

# %%
df_one = df.copy(deep=True)
df_one = df_one[["Area_Name","Year","Sub_Group_Name","Cases_Reported"]]
df_one
# Out:
#                       Area_Name  Year            Sub_Group_Name  \
# 0     Andaman & Nicobar Islands  2001                  01. Rape
# 1                Andhra Pradesh  2001                  01. Rape
# 2             Arunachal Pradesh  2001                  01. Rape
# 3                         Assam  2001                  01. Rape
# 4                         Bihar  2001                  01. Rape
# ...                         ...   ...                       ...
# 2445                 Tamil Nadu  2010  07. Importation of Girls
# 2446                    Tripura  2010  07. Importation of Girls
# 2447              Uttar Pradesh  2010  07. Importation of Girls
# 2448                Uttarakhand  2010  07. Importation of Girls
# 2449                West Bengal  2010  07. Importation of Girls
#
#       Cases_Reported
# 0                  3
# 1                871
# 2                 33
# 3                817
# 4                888
# ...              ...
# 2445               0
# 2446               0
# 2447               0
# 2448               0
# 2449               8
#
# [2450 rows x 4 columns]

# %%
y = df_one.pop('Cases_Reported')
X = df_one.copy(deep=True)
X
# Out:
#                       Area_Name  Year            Sub_Group_Name
# 0     Andaman & Nicobar Islands  2001                  01. Rape
# 1                Andhra Pradesh  2001                  01. Rape
# 2             Arunachal Pradesh  2001                  01. Rape
# 3                         Assam  2001                  01. Rape
# 4                         Bihar  2001                  01. Rape
# ...                         ...   ...                       ...
# 2445                 Tamil Nadu  2010  07. Importation of Girls
# 2446                    Tripura  2010  07. Importation of Girls
# 2447              Uttar Pradesh  2010  07. Importation of Girls
# 2448                Uttarakhand  2010  07. Importation of Girls
# 2449                West Bengal  2010  07. Importation of Girls
#
# [2450 rows x 3 columns]

# %%
seed = 50  # so that the result is reproducible
from sklearn.model_selection import train_test_split
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size = 0.1, random_state = seed)

# %%
train_features.dtypes
# Out:
# Area_Name         object
# Year               int64
# Sub_Group_Name    object
# dtype: object

# %%
features_to_encode = list(train_features.select_dtypes(include = ['object']).columns) 
# # Or alternatively, 
# features_to_encode = X_train.columns[X_train.dtypes==object].tolist()

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
col_trans = make_column_transformer(
                        (OneHotEncoder(),features_to_encode),
                        remainder = "passthrough"
                        )

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(
                      min_samples_leaf=50,
                      n_estimators=150,
                      bootstrap=True,
                      oob_score=True,
                      n_jobs=-1,
                      random_state=seed,
                      max_features='auto')

# %%
from sklearn.pipeline import make_pipeline
pipe = make_pipeline(col_trans, rf_classifier)
pipe.fit(train_features, train_labels)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['Area_Name',
#                                                    'Sub_Group_Name'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(min_samples_leaf=50, n_estimators=150,
#                                         n_jobs=-1, oob_score=True,
#                                         random_state=50))])

# %%
y_pred = pipe.predict(test_features)

# %%
MSE_error_rf2 = mean_squared_error(test_labels, predictions)
print('Root Mean Squared Error:',round((MSE_error_rf2**.5),2))
# Out:
# Root Mean Squared Error: 1865.43

# %%
mx=df["Cases_Reported"].max()
#print(mx)
mn=df['Cases_Reported'].min()
#print(mn)
normalised_rmse=(MSE_error_rf2**0.5)/(mx-mn)
print("Normalised RMSE for Random Forest 2 (One hot encoding): ",normalised_rmse)
# Out:
# Normalised RMSE for Random Forest 2 (One hot encoding):  0.10482295935943073

# %% [markdown]
# ## 4. SARIMAX

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.tsa.arima_model 
import statsmodels.api as sm
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error

# %%
dfs = df.copy(deep=True)
from sklearn import preprocessing
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
dfs['Area_Name']= label_encoder.fit_transform(dfs['Area_Name'])
dfs['Sub_Group_Name']= label_encoder.fit_transform(dfs['Sub_Group_Name'])
dfs.columns
# Out:
# Index(['Area_Name', 'Year', 'Sub_Group_Name', 'Cases_Acquitted_or_Discharged',
#        'Cases_charge_sheets_were_not_laid_but_Final_Report_submitted',
#        'Cases_Chargesheeted', 'Cases_Compounded_or_Withdrawn',
#        'Cases_Convicted',
#        'Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law',
#        'Cases_Investigated_Chargesheets+FR_Submitted',
#        'Cases_not_Investigated_or_in_which_investigation_was_refused',
#        'Cases_Pending_Investigation_at_Year_End',
#        'Cases_Pending_Investigation_from_previous_year',
#        'Cases_Pending_Trial_at_Year_End',
#        'Cases_Pending_Trial_from_the_previous_year', 'Cases_Reported',
#        'Cases_Sent_for_Trial', 'Cases_Trials_Completed',
#        'Cases_Withdrawn_by_the_Govt',
#        'Cases_withdrawn_by_the_Govt_during_investigation',
#        'Total_Cases_for_Trial', 'Persons_Acquitted',
#        'Persons_against_whom_cases_Compounded_or_Withdrawn',
#        'Persons_Arrested', 'Persons_Chargesheeted', 'Persons_Convicted',
#        'Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning'],
#       dtype='object')

# %%
dfs= dfs[["Year","Area_Name","Sub_Group_Name","Cases_Sent_for_Trial","Cases_Reported"]]
df
# Out:
#                       Area_Name  Year            Sub_Group_Name  \
# 0     Andaman & Nicobar Islands  2001                  01. Rape
# 1                Andhra Pradesh  2001                  01. Rape
# 2             Arunachal Pradesh  2001                  01. Rape
# 3                         Assam  2001                  01. Rape
# 4                         Bihar  2001                  01. Rape
# ...                         ...   ...                       ...
# 2445                 Tamil Nadu  2010  07. Importation of Girls
# 2446                    Tripura  2010  07. Importation of Girls
# 2447              Uttar Pradesh  2010  07. Importation of Girls
# 2448                Uttarakhand  2010  07. Importation of Girls
# 2449                West Bengal  2010  07. Importation of Girls
#
#       Cases_Acquitted_or_Discharged  \
# 0                                 5
# 1                               731
# 2                                 1
# 3                               334
# 4                               406
# ...                             ...
# 2445                              0
# 2446                              0
# 2447                              0
# 2448                              0
# 2449                              8
#
#       Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 0                                                     2
# 1                                                    22
# 2                                                     2
# 3                                                    95
# 4                                                   141
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#       Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# 0                       3                              0                0
# 1                     769                             35              197
# 2                      25                              0                2
# 3                     495                             10              101
# 4                     685                              0              155
# ...                   ...                            ...              ...
# 2445                    0                              0                0
# 2446                    0                              0                0
# 2447                    0                              0                0
# 2448                    0                              0                0
# 2449                    8                              0                0
#
#       Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# 0                                                     0
# 1                                                    74
# 2                                                     0
# 3                                                    45
# 4                                                   105
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  0
#
#       Cases_Investigated_Chargesheets+FR_Submitted  ...  \
# 0                                                5  ...
# 1                                              791  ...
# 2                                               27  ...
# 3                                              590  ...
# 4                                              826  ...
# ...                                            ...  ...
# 2445                                             0  ...
# 2446                                             0  ...
# 2447                                             0  ...
# 2448                                             0  ...
# 2449                                             8  ...
#
#       Cases_Trials_Completed  Cases_Withdrawn_by_the_Govt  \
# 0                          5                            0
# 1                        928                            2
# 2                          3                            0
# 3                        435                            0
# 4                        561                            0
# ...                      ...                          ...
# 2445                       0                            0
# 2446                       0                            0
# 2447                       0                            0
# 2448                       0                            0
# 2449                       8                            0
#
#       Cases_withdrawn_by_the_Govt_during_investigation  Total_Cases_for_Trial  \
# 0                                                    0                     39
# 1                                                    0                   2937
# 2                                                    0                    285
# 3                                                    0                   2409
# 4                                                    0                   3746
# ...                                                ...                    ...
# 2445                                                 0                      0
# 2446                                                 0                      0
# 2447                                                 0                      0
# 2448                                                 0                      0
# 2449                                                 0                     26
#
#       Persons_Acquitted  Persons_against_whom_cases_Compounded_or_Withdrawn  \
# 0                     6                                                  0
# 1                  1168                                                 13
# 2                     1                                                  0
# 3                   403                                                 14
# 4                   756                                                  0
# ...                 ...                                                ...
# 2445                  0                                                  0
# 2446                  0                                                  0
# 2447                  0                                                  0
# 2448                  0                                                  0
# 2449                 19                                                  0
#
#       Persons_Arrested  Persons_Chargesheeted  Persons_Convicted  \
# 0                    3                      3                  0
# 1                 1150                   1021                246
# 2                   51                     31                  2
# 3                  928                    585                120
# 4                 1400                   1302                217
# ...                ...                    ...                ...
# 2445                 0                      0                  0
# 2446                 0                      0                  0
# 2447                 0                      0                  0
# 2448                 0                      0                  0
# 2449                11                      8                  0
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning
# 0                                                     6
# 1                                                   450
# 2                                                    25
# 3                                                   806
# 4                                                   719
# ...                                                 ...
# 2445                                                  0
# 2446                                                  0
# 2447                                                  0
# 2448                                                  0
# 2449                                                  4
#
# [2450 rows x 27 columns]

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Cases Reported')
plt.plot(dfs['Cases_Reported'])
plt.title('Cases Reported')
plt.show()

# %%
#Test for stationarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of Dickey Fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
    
test_stationarity(dfs['Cases_Reported'])
# Out:
# Results of Dickey Fuller test
# Test Statistics                  -3.850455
# p-value                           0.002431
# No. of lags used                 27.000000
# Number of observations used    2422.000000
# critical value (1%)              -3.433053
# critical value (5%)              -2.862734
# critical value (10%)             -2.567406
# dtype: float64

# %%
result = seasonal_decompose(dfs['Cases_Reported'], model='additive',period=245)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
X_train, y_test = train_test_split(dfs, test_size=0.3, random_state=42)
X_train
# Out:
#       Year  Area_Name  Sub_Group_Name  Cases_Sent_for_Trial  Cases_Reported
# 519   2005         29               1                     2               2
# 308   2009         28               0                   967            1519
# 2032  2009          2               5                    14              13
# 2108  2001          8               6                     0               0
# 873   2005         33               2                    48              63
# ...    ...        ...             ...                   ...             ...
# 1638  2007         28               4                    19              28
# 1095  2002         10               3                    14              18
# 1130  2003         10               3                    11              19
# 1294  2007         34               3                  1585            2281
# 860   2005         20               2                   336             341
#
# [1715 rows x 5 columns]

# %%
df3 = X_train[["Area_Name","Sub_Group_Name","Year","Cases_Sent_for_Trial"]]
model_autoARIMA = auto_arima(X_train["Cases_Reported"], start_p=0, start_q=0,
                      test='adf',       # use adftest to find             optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      exogenous= df3)
print(model_autoARIMA.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=24242.010, Time=1.57 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=24241.553, Time=0.27 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=24241.505, Time=0.34 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=24243.395, Time=0.48 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=24243.371, Time=0.39 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=24245.362, Time=0.81 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=24243.504, Time=0.35 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 4.226 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1715
# Model:               SARIMAX(0, 0, 1)   Log Likelihood              -12114.752
# Date:                Thu, 10 Nov 2022   AIC                          24241.505
# Time:                        23:34:02   BIC                          24274.188
# Sample:                             0   HQIC                         24253.599
#                                - 1715
# Covariance Type:                  opg
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Area_Name                0.2595      0.667      0.389      0.697      -1.048       1.567
# Sub_Group_Name          -9.5521      5.018     -1.904      0.057     -19.387       0.282
# Year                     0.0317      0.010      3.212      0.001       0.012       0.051
# Cases_Sent_for_Trial     1.1576      0.003    413.539      0.000       1.152       1.163
# ma.L1                    0.0384      0.034      1.128      0.259      -0.028       0.105
# sigma2                8.015e+04    884.449     90.618      0.000    7.84e+04    8.19e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            110548.93
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.48   Skew:                             3.89
# Prob(H) (two-sided):                  0.00   Kurtosis:                        41.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model= SARIMAX(X_train['Cases_Reported'], 
exog=df3,
order=(0,0,1),
enforce_invertibility=False, enforce_stationarity=False)
# Out:
# c:\Users\tanvi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# c:\Users\tanvi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.

# %%
df_test3 = y_test[["Area_Name","Sub_Group_Name","Year","Cases_Sent_for_Trial"]]
results= model.fit()
forecast_1= results.forecast(steps=len(y_test), exog=df_test3)
# Out:
# c:\Users\tanvi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
print(forecast_1)
# Out:
# 1715    1469.964884
# 1716     203.346624
# 1717      11.319082
# 1718     449.425946
# 1719     435.504445
#            ...
# 2445     149.213600
# 2446    1215.084337
# 2447     876.332255
# 2448    8107.875989
# 2449     585.985792
# Name: predicted_mean, Length: 735, dtype: float64

# %%
train_data = df['Cases_Reported']
test = forecast_1
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Cases_Reported')
plt.plot(train_data, 'green', label='Train data')
plt.plot(test, 'blue', label='Test data')
plt.legend()

# %%
MSE_error_sarima = mean_squared_error(y_test['Cases_Reported'], forecast_1)
print('Root Mean Squared Error:',round((MSE_error_sarima**.5),2))
# Out:
# Root Mean Squared Error: 307.77

# %%
mx=df["Cases_Reported"].max()
#print(mx)
mn=df['Cases_Reported'].min()
#print(mn)
normalised_rmse=(MSE_error_sarima**0.5)/(mx-mn)
print("Normalised RMSE for Sarima : ",normalised_rmse)
# Out:
# Normalised RMSE for Sarima :  0.017294541940498103

# %% [markdown]
# ## Models to predict Cases Convicted
# STATE-WISE, YEAR-WISE, CRIME-WISE, USING CASES REPORTED

# %% [markdown]
# ## 1. ARIMAX

# %%
df1=df.groupby(['Area_Name', 'Year'],as_index=False)['Cases_Convicted','Persons_Convicted','Cases_Trials_Completed'].sum()
df_temp=df[(df["Area_Name"]=="West Bengal") & (df["Year"]==2006)]
df_temp["Cases_Convicted"].sum()
df1
df1.columns
df2=df1[(df1["Area_Name"]=="West Bengal")]
df2
# Out:
# C:\Users\Vishakha\AppData\Local\Temp\ipykernel_10184\1149494317.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#        Area_Name  Year  Cases_Convicted  Persons_Convicted  \
# 340  West Bengal  2001              282                544
# 341  West Bengal  2002              795               1150
# 342  West Bengal  2003              362                668
# 343  West Bengal  2004              365                663
# 344  West Bengal  2005              758               1127
# 345  West Bengal  2006              919               1982
# 346  West Bengal  2007              444                635
# 347  West Bengal  2008              526                627
# 348  West Bengal  2009              440                608
# 349  West Bengal  2010              417                579
#
#      Cases_Trials_Completed
# 340                    2439
# 341                    4981
# 342                    3865
# 343                    2756
# 344                    4403
# 345                    6435
# 346                    4854
# 347                    5057
# 348                    4773
# 349                    4451

# %%
plt.scatter(df1['Persons_Convicted'], df1['Cases_Convicted'], color='red')
plt.title('Cases convicted vs Persons convicted', fontsize=14)
plt.xlabel('Persons convicted', fontsize=14)
plt.ylabel('Cases convicted', fontsize=14)
plt.grid(True)
plt.show()

# %%
#Check for linearity between dependent variable (cases_convicted) and independent var (Cases_Trials_Completed)
plt.scatter(df1['Cases_Trials_Completed'], df1['Cases_Convicted'], color='red')
plt.title('Cases convicted vs Cases_Trials_Completed', fontsize=14)
plt.xlabel('Cases_Trials_Completed', fontsize=14)
plt.ylabel('Cases convicted', fontsize=14)
plt.grid(True)
plt.show()

# %%
ex = ['Persons_Convicted', 'Cases_Trials_Completed']
df_ar=df2
df_ar.set_index("Year", drop=False, inplace=True)


df_ar.Year = pd.to_datetime(df_ar.Year, format="%Y")

from pmdarima import auto_arima
df_train = df_ar[df_ar.Year < '2008']
df_valid = df_ar[df_ar.Year >= '2008']

model = auto_arima(df_train["Cases_Convicted"], exogenous=df_train[ex], trace=True, error_action="ignore", suppress_warnings=True)
model.fit(df_train["Cases_Convicted"], exogenous=df_train[ex])

forecast = model.predict(n_periods=len(df_valid), exogenous=df_valid[ex])
# Out:
# C:\Users\Vishakha\AppData\Local\Temp\ipykernel_10184\4254237980.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=100.384, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=102.014, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=111.620, Time=0.01 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.428 seconds
# c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %% [markdown]
# Since we were training on only 10 rows of data (crimes grouped year-wise from 2001 to 2010), there was not enough data to train the ARIMA model properly. Hence we decided not to go ahead with it.

# %% [markdown]
# ### Creating Train and Test Splits Along with Label Encoding

# %%
dfnew = df[["Area_Name","Year","Sub_Group_Name","Cases_Reported", "Cases_Convicted"]]

# %%
#CREATING DUMMY VARIABLES
import pandas as pd
dfn=pd.DataFrame(dfnew)
X = dfn.iloc[:, :-1].values
print(X)
# Out:
# [['Andaman & Nicobar Islands' 2001 '01. Rape' 3]
#  ['Andhra Pradesh' 2001 '01. Rape' 871]
#  ['Arunachal Pradesh' 2001 '01. Rape' 33]
#  ...
#  ['Uttar Pradesh' 2010 '07. Importation of Girls' 0]
#  ['Uttarakhand' 2010 '07. Importation of Girls' 0]
#  ['West Bengal' 2010 '07. Importation of Girls' 8]]

# %%
Y = dfn.iloc[:, 0].values
print(Y)
# Out:
# ['Andaman & Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh' ...
#  'Uttar Pradesh' 'Uttarakhand' 'West Bengal']

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
dfnew['Area_Name']= label_encoder.fit_transform(dfnew['Area_Name'])
dfnew['Sub_Group_Name']= label_encoder.fit_transform(dfnew['Sub_Group_Name'])
# Out:
# C:\Users\Vishakha\AppData\Local\Temp\ipykernel_10184\3113439619.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Vishakha\AppData\Local\Temp\ipykernel_10184\3113439619.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data=pd.DataFrame(dfnew)
y = data.pop('Cases_Convicted')
X=data

# %%
seed = 50  # so that the result is reproducible
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1, random_state = seed)

# %% [markdown]
# ## 2. KNN

# %%
#KNN REGRESSION
# Instance and fit
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
knn_model = KNeighborsRegressor(n_neighbors=5).fit(X_train, y_train)

# Score
score_knn = knn_model.score(X_test, y_test)
print(score_knn)

# Predictions
preds = knn_model.predict(X_test)

# Performance
performance = pd.DataFrame({ 'True Value': y_test,'Prediction': preds, 'Error': y_test - preds})
# View

mse_knn = mean_squared_error(y_test,preds)
print(mse_knn**0.5)
# Out:
# 0.08932580009062074
# 214.50140763536032

# %%
mx=df["Cases_Convicted"].max()
#print(mx)
mn=df['Cases_Convicted'].min()
#print(mn)
normalised_rmse=(mse_knn**0.5)/(mx-mn)
print("Normalised RMSE for KNN : ",normalised_rmse)
# Out:
# Normalised RMSE for KNN :  0.07093300517042339

# %% [markdown]
# ## 3.LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from numpy import absolute
from numpy import mean
from numpy import std
model = Lasso(alpha=1.0)
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Mean MAE: 91.474 (10.414)

# %%
model = Lasso(alpha=1.0)
# fit model
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# summarize prediction
#print('Predicted: %.3f' % y_pred[0])
lasso_mse = mean_squared_error(y_test,y_pred)
print("RMSE: ",lasso_mse**0.5)
# Out:
# RMSE:  201.6120393690843

# %%
mx=df["Cases_Convicted"].max()
mn=df['Cases_Convicted'].min()
normalised_rmse=(lasso_mse**0.5)/(mx-mn)
print("Normalised RMSE for Lasso regression : ",normalised_rmse)
# Out:
# Normalised RMSE for Lasso regression :  0.06667064793951201

# %% [markdown]
# ## 4. MLR

# %%
regr = linear_model.LinearRegression()
model = regr.fit(X_train,y_train)
r_sq = model.score(X_train, y_train)

y_pred = model.predict(X_test)

mlr_mse = mean_squared_error(y_test,y_pred)
print("RMSE: ",mlr_mse**0.5)
#summary=model.summary()
#print(y_pred)
print(r_sq)
# Out:
# RMSE:  201.60717047158815
# 0.43301884756356335

# %%
mx=df["Cases_Convicted"].max()
mn=df['Cases_Convicted'].min()
normalised_rmse=(mlr_mse**0.5)/(mx-mn)
print("Normalized rmse for MLR: ",normalised_rmse)
# Out:
# Normalized rmse for MLR:  0.06666903785436117

# %% [markdown]
# ## 5. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(
                      min_samples_leaf=50,
                      n_estimators=150, #150    
                      bootstrap=True,
                      oob_score=True,
                      n_jobs=-1,
                      random_state=seed,
                      max_features='auto')

# %%
rf_classifier.fit(X_train, y_train)
# Out:
# c:\Users\Vishakha\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning:
#
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
# RandomForestClassifier(max_features='auto', min_samples_leaf=50,
#                        n_estimators=150, n_jobs=-1, oob_score=True,
#                        random_state=50)

# %%
y_pred = rf_classifier.predict(X_test)

# %%
train_pred=rf_classifier.predict(X_train)

# %%
mse_test=mean_squared_error(train_pred,y_train)
print("RMSE of train: ",mse_test**0.5)
mse = mean_squared_error(y_test,y_pred)
print("RMSE of test: ",mse**0.5)
# Out:
# RMSE of train:  251.15839560432713
# RMSE of test:  167.98438945938048

# %%
mx=df["Cases_Convicted"].max()
mn=df['Cases_Convicted'].min()
normalised_rmse=(mse**0.5)/(mx-mn)
print(normalised_rmse)
# Out:
# 0.055550393339742224

# %%
df1=df[(df["Area_Name"]=="West Bengal") & df["Year"]>=2008]
df1
# Out:
# Empty DataFrame
# Columns: [Area_Name, Year, Sub_Group_Name, Cases_Acquitted_or_Discharged, Cases_charge_sheets_were_not_laid_but_Final_Report_submitted, Cases_Chargesheeted, Cases_Compounded_or_Withdrawn, Cases_Convicted, Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law, Cases_Investigated_Chargesheets+FR_Submitted, Cases_not_Investigated_or_in_which_investigation_was_refused, Cases_Pending_Investigation_at_Year_End, Cases_Pending_Investigation_from_previous_year, Cases_Pending_Trial_at_Year_End, Cases_Pending_Trial_from_the_previous_year, Cases_Reported, Cases_Sent_for_Trial, Cases_Trials_Completed, Cases_Withdrawn_by_the_Govt, Cases_withdrawn_by_the_Govt_during_investigation, Total_Cases_for_Trial, Persons_Acquitted, Persons_against_whom_cases_Compounded_or_Withdrawn, Persons_Arrested, Persons_Chargesheeted, Persons_Convicted, Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning]
# Index: []
#
# [0 rows x 27 columns]

# %%
print(df[(df["Area_Name"]=="West Bengal")])
# Out:
#         Area_Name  Year                  Sub_Group_Name  \
# 34    West Bengal  2001                        01. Rape
# 69    West Bengal  2002                        01. Rape
# 104   West Bengal  2003                        01. Rape
# 139   West Bengal  2004                        01. Rape
# 174   West Bengal  2005                        01. Rape
# ...           ...   ...                             ...
# 4024  West Bengal  2005  12. Total Crimes Against Women
# 4059  West Bengal  2006  12. Total Crimes Against Women
# 4094  West Bengal  2007  12. Total Crimes Against Women
# 4129  West Bengal  2009  12. Total Crimes Against Women
# 4164  West Bengal  2010  12. Total Crimes Against Women
#
#       Cases_Acquitted_or_Discharged  \
# 34                              517
# 69                              373
# 104                             394
# 139                             582
# 174                             473
# ...                             ...
# 4024                           3680
# 4059                           5544
# 4094                           4489
# 4129                           4362
# 4164                           4084
#
#       Cases_charge_sheets_were_not_laid_but_Final_Report_submitted  \
# 34                                                  133
# 69                                                  113
# 104                                                  53
# 139                                                 126
# 174                                                  75
# ...                                                 ...
# 4024                                                582
# 4059                                               1113
# 4094                                                738
# 4129                                                988
# 4164                                               1110
#
#       Cases_Chargesheeted  Cases_Compounded_or_Withdrawn  Cases_Convicted  \
# 34                    717                              0               45
# 69                    842                              0               63
# 104                   784                              0              113
# 139                  1244                              0              135
# 174                  1649                              0               74
# ...                   ...                            ...              ...
# 4024                11199                             34              812
# 4059                11445                             83             1001
# 4094                14424                             74              467
# 4129                18648                             65              467
# 4164                23528                            125              435
#
#       Cases_Declared_False_on_Account_of_Mistake_of_Fact_or_of_Law  \
# 34                                                    1
# 69                                                    6
# 104                                                  15
# 139                                                   7
# 174                                                   3
# ...                                                 ...
# 4024                                                 48
# 4059                                                 93
# 4094                                                 45
# 4129                                                 86
# 4164                                                120
#
#       Cases_Investigated_Chargesheets+FR_Submitted  ...  Persons_Arrested  \
# 34                                             850  ...              1027
# 69                                             955  ...              1279
# 104                                            837  ...              1497
# 139                                           1370  ...              1661
# 174                                           1724  ...              2085
# ...                                            ...  ...               ...
# 4024                                         11781  ...             19227
# 4059                                         12558  ...             22398
# 4094                                         15162  ...             22175
# 4129                                         19636  ...             20671
# 4164                                         24638  ...             26549
#
#       Persons_Chargesheeted  Persons_Convicted  \
# 34                      830                 54
# 69                     1137                 79
# 104                    1198                120
# 139                    1566                179
# 174                    1997                100
# ...                     ...                ...
# 4024                  17324               1261
# 4059                  18226               2077
# 4094                  22423                667
# 4129                  19766                651
# 4164                  28005                628
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_beginning  \
# 34                                                  762
# 69                                                  815
# 104                                                 868
# 139                                                1107
# 174                                                1147
# ...                                                 ...
# 4024                                               9661
# 4059                                               9949
# 4094                                              12225
# 4129                                              12419
# 4164                                              12367
#
#       Persons_in_Custody_or_on_Bail_during_Investigation_at_Year_end  \
# 34                                                  815
# 69                                                  868
# 104                                                1107
# 139                                                1147
# 174                                                1137
# ...                                                 ...
# 4024                                               9949
# 4059                                              12225
# 4094                                              10996
# 4129                                              12367
# 4164                                               9661
#
#       Persons_in_Custody_or_on_Bail_during_Trial_at_Year_End  \
# 34                                                 5943
# 69                                                 6510
# 104                                                7013
# 139                                                7595
# 174                                                8789
# ...                                                 ...
# 4024                                              73556
# 4059                                              80820
# 4094                                              91452
# 4129                                             109399
# 4164                                             124734
#
#       Persons_Released_or_Freed_by_Police_or_Magistrate_before_Trial_for_want_of_evidence_or_any_other_reason  \
# 34                                                  144
# 69                                                   89
# 104                                                  60
# 139                                                  55
# 174                                                  98
# ...                                                 ...
# 4024                                               1615
# 4059                                               1896
# 4094                                                981
# 4129                                                957
# 4164                                               1250
#
#       Persons_Trial_Completed  Persons_under_Trial_at_Year_beginning  \
# 34                        760                                   5873
# 69                        570                                   5943
# 104                       695                                   6510
# 139                       984                                   7013
# 174                       803                                   7595
# ...                       ...                                    ...
# 4024                     8995                                  65287
# 4059                    10798                                  73556
# 4094                    11409                                  80820
# 4129                    11717                                 101958
# 4164                    12000                                 109399
#
#       Total_Persons_under_Trial
# 34                         6703
# 69                         7080
# 104                        7708
# 139                        8579
# 174                        9592
# ...                         ...
# 4024                      82611
# 4059                      91782
# 4094                     103243
# 4129                     121724
# 4164                     137404
#
# [119 rows x 33 columns]
